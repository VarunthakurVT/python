# %%
print("hello ","World",end=".",sep="#")
# Out:
# hello #World.

# %%
try:
    a=1/0
    
except ZeroDivisionError:
    
    print("you can not divide any number by 0")
# Out:
# you can not divide any number by 0

# %%
students=[["varun","thakur"],["this is 2d list"]]

# %%
"name of the student is "+ students[0][0]

# %%
student=["varun","thakur","abc"]

# %%
student[2]="xyz"

# %%
student +students

# %%
student[0:2]

# %%
len(students)

# %%
a=int(3)
float(a)
print(type(a))

# %%
list=[1,2,3,4,5,6,7]
list.append(34)
list.insert(6,34)
list.pop()
list.sort()
list
# Out:
# [1, 2, 3, 4, 5, 6, 7, 34]

# %%
list[0]=3
list
# Out:
# [3, 2, 3, 4, 5, 6, 7, 34]

# %%
string=str("varun")
type(string)
string[0]
# Out:
# 'v'

# %%
tup=(1,3,4,5,6,5)
type(tup)
tup_=([23,34,5,4,34])
type(tup_)
# Out:
# list

# %%
a=3
b=43
a is b
# Out:
# False

# %%
dict={}
type(dict)
# Out:
# dict

# %%
print(r"hello \n anything")
print(f"hello \n anything")
# Out:
# hello \n anything
# hello
#  anything

# %%
'''this is the multiline comment'''
# Out:
# 'this is the multiline comment'

# %%
st="asdf jkl"
st.isupper()
# Out:
# False

# %%
st.startswith("asdf")
# Out:
# True

# %%
st.join("qwerty")
# Out:
# 'qasdfwasdfeasdfrasdftasdfy'

# %%
st.split('\n')
# Out:
# ['asdf']

# %%
"hello".center(30,'=')
# Out:
# '============hello============='

# %%
"   hello anythong".strip()
# Out:
# 'hello anythong'

# %%
import pyperclip as paper
paper.copy('hello')
paper.paste()
# Out:
# 'hello'

# %%
***
# Out:
# ['', 'aa', '']
